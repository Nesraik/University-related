# %% [markdown]
# # Training Phase

# %% [markdown]
# ## Importing library

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split
import os
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten, Concatenate
from tensorflow.keras.models import Model
import json
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Some code to support execution

# %%
tf.keras.backend.clear_session()

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
for gpu in physical_devices:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## Setting up the variable to contain data as well as displaying class names

# %%
data_path = 'image_dataset'

x,y = [],[]

class_names = os.listdir(data_path)

print(class_names)
# Out:
# ['battery', 'clothing_waste', 'glass', 'metal', 'organic', 'paper', 'plastic']

# %% [markdown]
# ## Function for resizing and padding

# %%
def pad_image(img):
    height, width = img.shape[:2]

    height_padding = (96 - height % 96) % 96
    width_padding = (96 - width % 96) % 96

    top_padding = height_padding // 2
    bottom_padding = height_padding - top_padding
    left_padding = width_padding // 2
    right_padding = width_padding - left_padding

    padded_img = cv2.copyMakeBorder(
        img, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=[0, 0, 0]
    )

    return padded_img

def resize_image(img):
    return cv2.resize(img, (96,96), interpolation=cv2.INTER_LANCZOS4)

# %% [markdown]
# ## Loading the data into x and y variable

# %%
for index, class_path in enumerate(class_names):
    for image in os.listdir(os.path.join(data_path, class_path)):
        
        img = cv2.imread(os.path.join(data_path, class_path, image))

        padded_img = pad_image(img)
        resized_img = resize_image(padded_img)

        rgb_img = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)
        
        x.append(rgb_img)
        y.append(index)

# %%
x,y = np.array(x),np.array(y)

# %% [markdown]
# ## The image count of each class/category

# %%
unique, counts = np.unique(y, return_counts=True)
category_counts = dict(zip(class_names, counts))

for category, count in category_counts.items():
    print(f"{category}: {count}")
# Out:
# battery: 945
# clothing_waste: 970
# glass: 1000
# metal: 999
# organic: 985
# paper: 1105
# plastic: 941

# %% [markdown]
# ## Sample image

# %%
fig, axes = plt.subplots(1, len(class_names), figsize=(20, 5))

for i, class_name in enumerate(class_names):
    class_index = class_names.index(class_name)
    image_index = np.where(y == class_index)[0][12]
    axes[i].imshow(x[image_index])
    axes[i].set_title(class_name)
    axes[i].axis('off')

plt.show()

# %% [markdown]
# ## Splitting data into training and testing

# %% [markdown]
# 80% for training, 10% for validation and 10% for testing

# %%
x_train,x_temp,y_train,y_temp = train_test_split(x,y,test_size=0.2,stratify=y,random_state=42)

x_val,x_test,y_val,y_test = train_test_split(x_temp,y_temp,test_size=0.5,stratify=y_temp,random_state=42)

# %%
x_train.shape
# Out:
# (5556, 96, 96, 3)

# %% [markdown]
# ## Data augmentation

# %%
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(

    rotation_range=20,

    width_shift_range=0.14,

    height_shift_range=0.14,

    horizontal_flip=True,

    zoom_range=0.11,

    brightness_range=[0.9,1.1],

    shear_range=0.12,

    channel_shift_range=0.1,

)

# %%
x_train = data_generator.flow(x_train, y_train, batch_size=len(x_train))
x_train,y_train = next(x_train)

# %% [markdown]
# ## Extracting akaze feature

# %% [markdown]
# Finding max length of keypoint and descriptor

# %%
def extractAKAZE_no_padding(img):
    img = img.astype(np.uint8)
    gray_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    blur_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
    akaze = cv2.AKAZE_create()
    kp, des = akaze.detectAndCompute(blur_image, None)
    return kp,des 

keypoints,descriptors = zip(*[extractAKAZE_no_padding(img) for img in x_train])

max_keypoints = max(len(kp) for kp in keypoints)
print(f"Maximum keypoints found in any image: {max_keypoints}")

# Calculate maximum number of descriptors in any image
max_descriptors = max(des.shape[0] if des is not None else 0 for des in descriptors)
print(f"Maximum descriptors found in any image: {max_descriptors}")
# Out:
# Maximum keypoints found in any image: 28
# Maximum descriptors found in any image: 28

# %%
def extract_akaze_features(img, max_keypoints=max_keypoints, max_descriptors=max_descriptors):
    img = img.astype(np.uint8)
    gray_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    blur_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
    akaze = cv2.AKAZE_create()
    keypoints, descriptor = akaze.detectAndCompute(blur_image, None)
    
    
    keypoint_positions = []
    keypoint_sizes = []
    keypoint_angles = []

     
    if keypoints:
        for kp in keypoints:
            keypoint_positions.append([kp.pt[0], kp.pt[1]])  # (x, y)
            keypoint_sizes.append(kp.size)
            keypoint_angles.append(kp.angle)

        
        keypoint_positions = np.array(keypoint_positions)
        keypoint_sizes = np.array(keypoint_sizes)
        keypoint_angles = np.array(keypoint_angles)

        
        if keypoint_positions.shape[0] < max_keypoints:
            pad_length = max_keypoints - keypoint_positions.shape[0]
            keypoint_positions = np.pad(keypoint_positions, ((0, pad_length), (0, 0)), mode='constant')
            keypoint_sizes = np.pad(keypoint_sizes, (0, pad_length), mode='constant')
            keypoint_angles = np.pad(keypoint_angles, (0, pad_length), mode='constant')

        
        else:
            keypoint_positions = keypoint_positions[:max_keypoints]
            keypoint_sizes = keypoint_sizes[:max_keypoints]
            keypoint_angles = keypoint_angles[:max_keypoints]

        # Calculate aggregated keypoint stats (mean and std)
        keypoint_stats = np.concatenate([
            np.mean(keypoint_positions, axis=0),  # mean (x, y)
            np.std(keypoint_positions, axis=0),   # std (x, y)
            [np.mean(keypoint_sizes), np.std(keypoint_sizes)],  # mean and std of sizes
            [np.mean(keypoint_angles), np.std(keypoint_angles)]  # mean and std of angles
        ])
    else:
        
        keypoint_stats = np.zeros(8)

    if descriptor is not None:
        
        if descriptor.shape[0] > max_descriptors:
            descriptor = descriptor[:max_descriptors]
        elif descriptor.shape[0] < max_descriptors:
            padding = np.zeros((max_descriptors - descriptor.shape[0], descriptor.shape[1]))
            descriptor = np.vstack([descriptor, padding])
        descriptor = descriptor.flatten()  # Flatten to 1D
        #print(descriptor.shape)
    else:
        
        descriptor = np.zeros(max_descriptors * 61) 

    return keypoint_stats, descriptor

# %% [markdown]
# Extracting keypoints and descriptors of each image

# %%
x_train_keypoints, x_train_descriptors = zip(*[extract_akaze_features(img) for img in x_train])
x_train_keypoints = np.array(x_train_keypoints)
x_train_descriptors = np.array(x_train_descriptors)

x_test_keypoints, x_test_descriptors = zip(*[extract_akaze_features(img) for img in x_test])
x_test_keypoints = np.array(x_test_keypoints)
x_test_descriptors = np.array(x_test_descriptors)

x_val_keypoints, x_val_descriptors = zip(*[extract_akaze_features(img) for img in x_val])
x_val_keypoints = np.array(x_val_keypoints)
x_val_descriptors = np.array(x_val_descriptors)

# %% [markdown]
# ## Normalizing to 0-1

# %%
x_train = x_train.astype("float32")/255.0
x_test = x_test.astype("float32")/255.0
x_val = x_val.astype("float32")/255.0

# %% [markdown]
# ## Model architecture

# %%
# Image branch (ResNet for visual features)
image_input = Input(shape=(96, 96, 3), name="image_input")
resnet_model = tf.keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_tensor=image_input,
    pooling="avg"
)

# Descriptor branch (aggregated feature descriptor from ORB
descriptor_input = Input(shape=(x_train_descriptors[0].shape), name="descriptor_input")  
x_descriptor = Dense(64, activation="relu")(descriptor_input)
x_descriptor = BatchNormalization()(x_descriptor)
x_descriptor = Dropout(0.25)(x_descriptor)

# Keypoint branch (aggregated feature descriptor from ORB
keypoint_input = Input(shape=(x_train_keypoints[0].shape), name="keypoint_input")  
x_keypoint = Dense(32, activation="relu")(keypoint_input)
x_keypoint = BatchNormalization()(x_keypoint)
x_keypoint = Dropout(0.25)(x_keypoint)

# Combine the branches
x_combined = Concatenate()([resnet_model.output, x_descriptor,x_keypoint])
x_combined = Dense(128, activation="relu")(x_combined)
x_combined = BatchNormalization()(x_combined)
x_combined = Dropout(0.25)(x_combined)
x_combined = Dense(80, activation="relu")(x_combined)
x_combined = BatchNormalization()(x_combined)
x_combined = Dropout(0.25)(x_combined)
x_combined = Dense(64, activation="relu")(x_combined)
x_combined = BatchNormalization()(x_combined)
x_combined = Dropout(0.25)(x_combined)

# Output layer
output = Dense(7, activation="softmax")(x_combined)


model = Model(inputs=[image_input, descriptor_input,keypoint_input], outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 96, 96, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 102, 102, 3)  0           ['image_input[0][0]']
#
#  conv1_conv (Conv2D)            (None, 48, 48, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 48, 48, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 48, 48, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 50, 50, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 24, 24, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 24, 24, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 24, 24, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 24, 24, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 24, 24, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 24, 24, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 24, 24, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 24, 24, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 24, 24, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 24, 24, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 24, 24, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 24, 24, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 24, 24, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 24, 24, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 24, 24, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 24, 24, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 24, 24, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 24, 24, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 24, 24, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 24, 24, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 24, 24, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 24, 24, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 24, 24, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 24, 24, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 24, 24, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 24, 24, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 24, 24, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 24, 24, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 24, 24, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 24, 24, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 24, 24, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 24, 24, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 24, 24, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 12, 12, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 12, 12, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 12, 12, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 12, 12, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 12, 12, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 12, 12, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 12, 12, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 12, 12, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 12, 12, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 12, 12, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 12, 12, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 12, 12, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 12, 12, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 12, 12, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 12, 12, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 12, 12, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 12, 12, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 12, 12, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 12, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 12, 12, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 12, 12, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 12, 12, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 6, 6, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 6, 6, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 6, 6, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 6, 6, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 6, 6, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 6, 6, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 6, 6, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 6, 6, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 6, 6, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 6, 6, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 6, 6, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 6, 6, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 6, 6, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 6, 6, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 6, 6, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 6, 6, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 6, 6, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 6, 6, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 6, 6, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 6, 6, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 6, 6, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 6, 6, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 6, 6, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 6, 6, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 6, 6, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 6, 6, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 6, 6, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 6, 6, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 6, 6, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 6, 6, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 6, 6, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 6, 6, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 3, 3, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 3, 3, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 3, 3, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 3, 3, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 3, 3, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 3, 3, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 3, 3, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 3, 3, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 3, 3, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 3, 3, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 3, 3, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 3, 3, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 3, 3, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 3, 3, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 3, 3, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 3, 3, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 3, 3, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 3, 3, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 3, 3, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 3, 3, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  descriptor_input (InputLayer)  [(None, 1708)]       0           []
#
#  keypoint_input (InputLayer)    [(None, 8)]          0           []
#
#  conv5_block3_add (Add)         (None, 3, 3, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  dense (Dense)                  (None, 64)           109376      ['descriptor_input[0][0]']
#
#  dense_1 (Dense)                (None, 32)           288         ['keypoint_input[0][0]']
#
#  conv5_block3_out (Activation)  (None, 3, 3, 2048)   0           ['conv5_block3_add[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64)          256         ['dense[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 32)          128         ['dense_1[0][0]']
#  rmalization)
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  dropout (Dropout)              (None, 64)           0           ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 32)           0           ['batch_normalization_1[0][0]']
#
#  concatenate (Concatenate)      (None, 2144)         0           ['avg_pool[0][0]',
#                                                                   'dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          274560      ['concatenate[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 128)         512         ['dense_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 128)          0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 80)           10320       ['dropout_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 80)          320         ['dense_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 80)           0           ['batch_normalization_3[0][0]']
#
#  dense_4 (Dense)                (None, 64)           5184        ['dropout_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64)          256         ['dense_4[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 64)           0           ['batch_normalization_4[0][0]']
#
#  dense_5 (Dense)                (None, 7)            455         ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 23,989,367
# Trainable params: 23,935,511
# Non-trainable params: 53,856
# __________________________________________________________________________________________________

# %% [markdown]
# ## Setting up the data to feed the model

# %%
train_data = {"image_input": x_train, "descriptor_input": x_train_descriptors, "keypoint_input": x_train_keypoints}
val_data = {"image_input": x_val, "descriptor_input": x_val_descriptors, "keypoint_input": x_val_keypoints}
test_data = {"image_input": x_test, "descriptor_input": x_test_descriptors, "keypoint_input": x_test_keypoints}

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(verbose=1, patience=10, monitor="val_loss", restore_best_weights=True)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(15e-6), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_data, y_train, validation_data=(val_data, y_val), epochs=30, batch_size=8,callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 695/695 [==============================] - 74s 92ms/step - loss: 2.4944 - accuracy: 0.1965 - val_loss: 4.0176 - val_accuracy: 0.1988
# Epoch 2/30
# 695/695 [==============================] - 66s 95ms/step - loss: 2.0480 - accuracy: 0.3031 - val_loss: 2.0472 - val_accuracy: 0.4452
# Epoch 3/30
# 695/695 [==============================] - 68s 98ms/step - loss: 1.7744 - accuracy: 0.3904 - val_loss: 1.5809 - val_accuracy: 0.5231
# Epoch 4/30
# 695/695 [==============================] - 68s 98ms/step - loss: 1.5903 - accuracy: 0.4602 - val_loss: 1.3628 - val_accuracy: 0.5965
# Epoch 5/30
# 695/695 [==============================] - 68s 98ms/step - loss: 1.4584 - accuracy: 0.5067 - val_loss: 1.1727 - val_accuracy: 0.6369
# Epoch 6/30
# 695/695 [==============================] - 68s 98ms/step - loss: 1.3364 - accuracy: 0.5495 - val_loss: 1.2387 - val_accuracy: 0.6931
# Epoch 7/30
# 695/695 [==============================] - 68s 98ms/step - loss: 1.2260 - accuracy: 0.5830 - val_loss: 0.9303 - val_accuracy: 0.7089
# Epoch 8/30
# 695/695 [==============================] - 68s 98ms/step - loss: 1.1695 - accuracy: 0.6048 - val_loss: 0.8505 - val_accuracy: 0.7421
# Epoch 9/30
# 695/695 [==============================] - 68s 98ms/step - loss: 1.0963 - accuracy: 0.6377 - val_loss: 0.9376 - val_accuracy: 0.7565
# Epoch 10/30
# 695/695 [==============================] - 68s 98ms/step - loss: 1.0266 - accuracy: 0.6564 - val_loss: 0.8952 - val_accuracy: 0.7867
# Epoch 11/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.9637 - accuracy: 0.6830 - val_loss: 0.8486 - val_accuracy: 0.7983
# Epoch 12/30
# 695/695 [==============================] - 68s 99ms/step - loss: 0.9228 - accuracy: 0.7048 - val_loss: 0.7853 - val_accuracy: 0.8069
# Epoch 13/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.9020 - accuracy: 0.7025 - val_loss: 0.6341 - val_accuracy: 0.8170
# Epoch 14/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.8550 - accuracy: 0.7196 - val_loss: 0.6650 - val_accuracy: 0.8184
# Epoch 15/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.8150 - accuracy: 0.7347 - val_loss: 0.5664 - val_accuracy: 0.8343
# Epoch 16/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.7581 - accuracy: 0.7577 - val_loss: 0.7774 - val_accuracy: 0.8372
# Epoch 17/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.7249 - accuracy: 0.7691 - val_loss: 0.7304 - val_accuracy: 0.8256
# Epoch 18/30
# 695/695 [==============================] - 69s 99ms/step - loss: 0.6820 - accuracy: 0.7784 - val_loss: 0.5731 - val_accuracy: 0.8559
# Epoch 19/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.6622 - accuracy: 0.7864 - val_loss: 0.7753 - val_accuracy: 0.8530
# Epoch 20/30
# 695/695 [==============================] - 69s 99ms/step - loss: 0.6030 - accuracy: 0.8074 - val_loss: 0.5216 - val_accuracy: 0.8775
# Epoch 21/30
# 695/695 [==============================] - 69s 99ms/step - loss: 0.6050 - accuracy: 0.8074 - val_loss: 0.5141 - val_accuracy: 0.8718
# Epoch 22/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.5488 - accuracy: 0.8242 - val_loss: 0.5430 - val_accuracy: 0.8775
# Epoch 23/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.5228 - accuracy: 0.8328 - val_loss: 0.5636 - val_accuracy: 0.8631
# Epoch 24/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.4873 - accuracy: 0.8492 - val_loss: 0.5183 - val_accuracy: 0.8617
# Epoch 25/30
# 695/695 [==============================] - 69s 99ms/step - loss: 0.4634 - accuracy: 0.8530 - val_loss: 0.4623 - val_accuracy: 0.8862
# Epoch 26/30
# 695/695 [==============================] - 68s 98ms/step - loss: 0.4332 - accuracy: 0.8643 - val_loss: 0.5995 - val_accuracy: 0.8732
# Epoch 27/30
# 695/695 [==============================] - 69s 100ms/step - loss: 0.4418 - accuracy: 0.8621 - val_loss: 0.5921 - val_accuracy: 0.8876
# Epoch 28/30
# 695/695 [==============================] - 70s 101ms/step - loss: 0.3954 - accuracy: 0.8778 - val_loss: 0.4832 - val_accuracy: 0.8818
# Epoch 29/30
# 695/695 [==============================] - 70s 100ms/step - loss: 0.3751 - accuracy: 0.8850 - val_loss: 0.4614 - val_accuracy: 0.8775
# Epoch 30/30
# 695/695 [==============================] - 70s 100ms/step - loss: 0.3679 - accuracy: 0.8880 - val_loss: 0.4848 - val_accuracy: 0.8790

# %% [markdown]
# # Evaluation Phase

# %% [markdown]
# ## Accuracy & Loss vs EPOCH

# %%
print(model.evaluate(test_data, y_test))
# Out:
# 22/22 [==============================] - 1s 54ms/step - loss: 0.3499 - accuracy: 0.8906
# [0.34991151094436646, 0.8906474709510803]

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],label = "Training Accuracy")
plt.plot(history.history['val_accuracy'],label = "Validation Accuracy")
plt.legend()
plt.xlabel('EPOCH')
plt.ylabel("Accuracy")

plt.subplot(1,2,2)
plt.plot(history.history['loss'],label = "Training Loss")
plt.plot(history.history['val_loss'],label = "Validation Loss")
plt.legend()
plt.xlabel('EPOCH')
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ## Classification report and confusion matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

predictions = model.predict(test_data)

y_pred = np.argmax(predictions, axis=1)


print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# 22/22 [==============================] - 2s 42ms/step
#                 precision    recall  f1-score   support
#
#        battery       0.91      0.96      0.93        94
# clothing_waste       0.91      0.95      0.93        97
#          glass       0.90      0.83      0.86       100
#          metal       0.80      0.90      0.85       100
#        organic       0.95      0.90      0.92        99
#          paper       0.86      0.96      0.91       111
#        plastic       0.94      0.72      0.82        94
#
#       accuracy                           0.89       695
#      macro avg       0.90      0.89      0.89       695
#   weighted avg       0.89      0.89      0.89       695

# %%
display = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred), display_labels=class_names)
display.plot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Save model

# %%
model.save("akaze_model.h5")
max_feature_length = {'max_keypoint': max_keypoints, 'max_descriptor': max_descriptors}
with open('max_feature_length_akze.json', 'w') as file:
    json.dump(max_feature_length, file)

# %% [markdown]
# # Testing phase

# %% [markdown]
# ## Run all of this if you want to test on new images

# %% [markdown]
# Load model

# %%
akaze_model = load_model("akaze_model.h5")

with open('max_feature_length_akaze.json', 'r') as file:
    max_feature_length = json.load(file)

max_keypoint = max_feature_length['max_keypoint']
max_descriptor = max_feature_length['max_descriptor']

print(max_keypoint, max_descriptor)
# Out:
# 28 28

# %% [markdown]
# Padding and resizing

# %%
def pad_image(img):
    height, width = img.shape[:2]

    height_padding = (96 - height % 96) % 96
    width_padding = (96 - width % 96) % 96

    top_padding = height_padding // 2
    bottom_padding = height_padding - top_padding
    left_padding = width_padding // 2
    right_padding = width_padding - left_padding

    padded_img = cv2.copyMakeBorder(
        img, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=[0, 0, 0]
    )

    return padded_img

def resize_image(img):
    return cv2.resize(img, (96,96), interpolation=cv2.INTER_LANCZOS4)

# %% [markdown]
# AKAZE extractor

# %%
def extract_akaze_features(img, max_keypoints=max_keypoint, max_descriptors=max_descriptor):
    img = img.astype(np.uint8)
    gray_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    blur_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
    akaze = cv2.AKAZE_create()
    keypoints, descriptor = akaze.detectAndCompute(blur_image, None)
    
    
    keypoint_positions = []
    keypoint_sizes = []
    keypoint_angles = []

    
    if keypoints:
        for kp in keypoints:
            keypoint_positions.append([kp.pt[0], kp.pt[1]])  # (x, y)
            keypoint_sizes.append(kp.size)
            keypoint_angles.append(kp.angle)

        
        keypoint_positions = np.array(keypoint_positions)
        keypoint_sizes = np.array(keypoint_sizes)
        keypoint_angles = np.array(keypoint_angles)

        
        if keypoint_positions.shape[0] < max_keypoints:
            pad_length = max_keypoints - keypoint_positions.shape[0]
            keypoint_positions = np.pad(keypoint_positions, ((0, pad_length), (0, 0)), mode='constant')
            keypoint_sizes = np.pad(keypoint_sizes, (0, pad_length), mode='constant')
            keypoint_angles = np.pad(keypoint_angles, (0, pad_length), mode='constant')

       
        else:
            keypoint_positions = keypoint_positions[:max_keypoints]
            keypoint_sizes = keypoint_sizes[:max_keypoints]
            keypoint_angles = keypoint_angles[:max_keypoints]

        # Calculate aggregated keypoint stats (mean and std)
        keypoint_stats = np.concatenate([
            np.mean(keypoint_positions, axis=0),  # mean (x, y)
            np.std(keypoint_positions, axis=0),   # std (x, y)
            [np.mean(keypoint_sizes), np.std(keypoint_sizes)],  # mean and std of sizes
            [np.mean(keypoint_angles), np.std(keypoint_angles)]  # mean and std of angles
        ])
    else:
        
        keypoint_stats = np.zeros(8)

    if descriptor is not None:
        
        if descriptor.shape[0] > max_descriptors:
            descriptor = descriptor[:max_descriptors]
        elif descriptor.shape[0] < max_descriptors:
            padding = np.zeros((max_descriptors - descriptor.shape[0], descriptor.shape[1]))
            descriptor = np.vstack([descriptor, padding])
        descriptor = descriptor.flatten()  # Flatten to 1D
        #print(descriptor.shape)
    else:
        
        descriptor = np.zeros(max_descriptors * 61) 

    return keypoint_stats, descriptor

# %% [markdown]
# Image label

# %%
class_names = ['battery', 'clothing_waste', 'glass', 'metal', 'organic', 'paper', 'plastic']

# %% [markdown]
# Function for predicting image

# %%
def predict_image(image_path):
    #Read image
    image = cv2.imread(image_path)

    #Resize image
    image = resize_image(image)

    #Pad image
    image = pad_image(image)

    #Convert to RGB
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    #Convert to array 
    image = np.array(image)

    #Extract feature
    keypoints, descriptors = extract_akaze_features(image)

    #Normalize image
    image = image.astype("float32")/255.0

    #Format data
    image_data = {"image_input": np.expand_dims(image, axis=0), "descriptor_input": np.expand_dims(descriptors, axis=0), "keypoint_input": np.expand_dims(keypoints, axis=0)}

    #Predict
    image_prediction = akaze_model.predict(image_data)
    
    #Get class
    image_class = class_names[np.argmax(image_prediction)]

    return image_class

# %% [markdown]
# ## Test your images

# %% [markdown]
# Battery

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_battery.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_battery.jpg"))
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Text(0.5, 1.0, 'glass')

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_battery_2.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_battery_2.jpg"))
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Text(0.5, 1.0, 'glass')

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_battery_3.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_battery_3.jpg"))
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Text(0.5, 1.0, 'paper')

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_battery_4.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_battery_4.jpg"))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# Text(0.5, 1.0, 'battery')

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_battery_5.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_battery_5.jpg"))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# Text(0.5, 1.0, 'battery')

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_battery_6.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_battery_6.jpg"))
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Text(0.5, 1.0, 'battery')

# %% [markdown]
# Plastic

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_plastic.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_plastic.jpg"))
# Out:
# 1/1 [==============================] - 0s 30ms/step
# Text(0.5, 1.0, 'plastic')

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_plastic_2.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_plastic_2.jpg"))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# Text(0.5, 1.0, 'plastic')

# %% [markdown]
# Cloth

# %%
plt.imshow(cv2.cvtColor(cv2.imread("sample_cloth.jpg"), cv2.COLOR_BGR2RGB))
plt.title(predict_image("sample_cloth.jpg"))
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Text(0.5, 1.0, 'clothing_waste')
